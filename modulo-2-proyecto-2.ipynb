# %%
import pandas as pd
import numpy as np
import pickle

# %%
archivo_csv = pd.read_csv("data/exported_db_data.csv")
#archivo_csv.head()
archivo_csv
# Out:
#        index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4  \
# 0          0                NaN  Colab Notebooks        NaN        NaN
# 1          1   Kaggle Notebooks  Colab Notebooks        NaN        NaN
# 2          2   Kaggle Notebooks              NaN        NaN        NaN
# 3          3                NaN  Colab Notebooks        NaN        NaN
# 4          4                NaN              NaN        NaN        NaN
# ...      ...                ...              ...        ...        ...
# 25968  25968                NaN  Colab Notebooks        NaN        NaN
# 25969  25969                NaN              NaN        NaN        NaN
# 25970  25970                NaN              NaN        NaN        NaN
# 25971  25971                NaN              NaN        NaN        NaN
# 25972  25972                NaN              NaN        NaN        NaN
#
#       Q10_Part_5 Q10_Part_6 Q10_Part_7                           Q10_Part_8  \
# ...

# %%
archivo_txt = pd.read_clipboard(sep = ';')
#archivo_txt.head()
archivo_txt.head()
archivo_txt.to_csv("data/archivo_txt.csv")

# %%
archivo_csv_txt = pd.read_csv("data/archivo_txt.csv")
archivo_csv_txt
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, /DATOS/attacks.csv]
# Index: []

# %%
archivo_xml = pd.read_xml("data/data_xml_clean.xml")
#archivo_xml.head(20)
archivo_xml
# Out:
#        level_0  index  time    age gender
# 0            0      0   910  50-54    Man
# 1            1      1   784  50-54    Man
# 2            2      2   924  22-24    Man
# 3            3      3   575  45-49    Man
# 4            4      4   781  45-49    Man
# ...        ...    ...   ...    ...    ...
# 25968    25968  25968  1756  30-34    Man
# 25969    25969  25969   253  22-24    Man
# 25970    25970  25970   494  50-54    Man
# 25971    25971  25971   277  45-49    Man
# 25972    25972  25972   255  18-21    Man
#
# [25973 rows x 5 columns]

# %%
archivo_xml["age"].value_counts()
# Out:
# 25-29    4931
# 18-21    4901
# 22-24    4694
# 30-34    3441
# 35-39    2504
# 40-44    1890
# 45-49    1375
# 50-54     964
# 55-59     592
# 60-69     553
# 70+       128
# Name: age, dtype: int64

# %%
archivo_kaggle_csv = pd.read_csv("data/data_remaning_kaggle.csv")
#archivo_kaggle_csv.head()
archivo_kaggle_csv
# Out:
#        Unnamed: 0  index                                         Q18_Part_1  \
# 0               0      0  General purpose image/video tools (PIL, cv2, s...
# 1               1      1                                                NaN
# 2               2      2                                                NaN
# 3               3      3  General purpose image/video tools (PIL, cv2, s...
# 4               4      4                                                NaN
# ...           ...    ...                                                ...
# 25968       25968  25968  General purpose image/video tools (PIL, cv2, s...
# 25969       25969  25969                                                NaN
# 25970       25970  25970                                                NaN
# 25971       25971  25971                                                NaN
# 25972       25972  25972                                                NaN
#
# ...

# %% [markdown]
# Después de leer los ficheros hemos averiguado que todos tienen el mismo número de filas 25973

# %% [markdown]
# 5. ¿Cuánto se cobra de media en base al tiempo trabajado/experiencia? (q25)

# %% [markdown]
# 6. Diferencia de salarios medios entre hombres y mujeres en medio (q25,q2)

# %% [markdown]
# 10. Tipos de formación, tales como bootcamp, máster, para conseguir un puesto de trabajo relacionado con su puesto de trabajo.

# %% [markdown]
# 11. Lenguajes de programación prioritarios tanto para hombres como para mujeres.

# %% [markdown]
# 12. Qué sectores son los que más demandan analítica de datos. (q20,q21,q22)

# %% [markdown]
# 14. Necesidad de formación para trabajar en senior cuando ya estamos en junior

# %% [markdown]
# Hacer preguntas sencillas siempre pero mirar la respuesta en base al genero y en base al pais

# %%
"""Q2--- Porcentaje de genero entrevistado
Q3--- Paises de residencia
Q4--- Nivel de educación de cara a 2 años
Q5--- Rol actual, equivalente
Q6--- Años de experiencia en programación
Q7--- Lenguajes de programación que utilizas
Q8--- Programas que recomiendas aprender a un aspirante de cientifico de datos
Q11-- Plataformas usas como data science
Q14-- Que librerias/herramientas de visualización usas
Q15-- Cuanto tiempo hace que usas métodos de machine learning
Q20-- En qué sector trabajas
Q21-- Tamaño de la compañía(referencia a la q20)
Q22-- Cuanta gente hay en tu departamento(referente a la q20)
Q25-- Salario
"""
