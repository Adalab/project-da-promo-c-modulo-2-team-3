# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tabla_pequeña = pd.read_csv("data/tabla_pequeña.csv", index_col =0)
tabla_pequeña.head(5)
# Out:
#    indices   edad genero       pais        formacion_2  \
# 0        0  50-54    Man      India  Bachelor’s degree
# 1        1  50-54    Man  Indonesia    Master’s degree
# 2        2  22-24    Man   Pakistan    Master’s degree
# 3        3  45-49    Man     Mexico    Doctoral degree
# 4        4  45-49    Man      India    Doctoral degree
#
#             puesto_trabajo años_programando lenguajes_utilizados  \
# 0                    Other       5-10 years            Python, R
# 1  Program/Project Manager        20+ years    SQL, C, C++, Java
# 2        Software Engineer        1-3 years    Python, C++, Java
# 3       Research Scientist        20+ years               Python
# 4                    Other        < 1 years    Python, C, MATLAB
#
#   lenguajes_recomendados                                   herramientas_uso  \
# 0                 Python                                           A laptop
# 1                 Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2                 Python                                           A laptop
# 3                 Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4                 Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#    ... fuente_conocimiento_reddit       fuente_conocimiento_kaggle  \
# 0  ...                        NaN  Kaggle (notebooks, forums, etc)
# 1  ...                        NaN                              NaN
# 2  ...                        NaN  Kaggle (notebooks, forums, etc)
# 3  ...                        NaN                              NaN
# 4  ...                        NaN                              NaN
#
#   fuente_conocimiento_course  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#                          fuente_conocimiento_youtube  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
# 2  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 3  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4                                                NaN
#
#                          fuente_conocimiento_podcast  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            fuente_conocimiento_blogs  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
# 2                                                NaN
# 3  Blogs (Towards Data Science, Analytics Vidhya,...
# 4                                                NaN
#
#             fuente_conocimiento_journal_publicacions  \
# 0  Journal Publications (peer-reviewed journals, ...
# 1  Journal Publications (peer-reviewed journals, ...
# 2                                                NaN
# 3  Journal Publications (peer-reviewed journals, ...
# 4  Journal Publications (peer-reviewed journals, ...
#
#   fuente_conocimiento_slack_communities fuente_conocimiento_none  \
# 0                                   NaN                      NaN
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
#
#   fuente_conocimiento_otros
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 41 columns]

# %%
tabla_pequeña.duplicated().sum()
# Out:
# 0

# %%
tabla_pequeña.columns
# Out:
# Index(['Unnamed: 0', 'indices', 'edad', 'genero', 'pais', 'formacion_2',
#        'puesto_trabajo', 'años_programando', 'lenguajes_utilizados',
#        'lenguajes_recomendados', 'herramientas_uso', 'librerias_visualizacion',
#        'años_usando_machine', 'sector_trabajo_actual', 'tamaño_empresa',
#        'personas_dpt_data', 'salario_anual', 'inversion_dpt_machine_5años',
#        'plataforma_coursera', 'plataforma_edx',
#        'plataforma_kaggle_learn_courses', 'plataforma_data_camp',
#        'plataforma_fast_ai', 'plataforma_udacity', 'plataforma_udemy',
#        'plataforma_linkedin_learning',
#        'plataforma_cloud_certification_programs',
#        'plataforma_university_courses', 'plataforma_none', 'plataforma_otros',
#        'fuente_conocimiento_twitter', 'fuente_conocimiento_email',
#        'fuente_conocimiento_reddit', 'fuente_conocimiento_kaggle',
#        'fuente_conocimiento_course', 'fuente_conocimiento_youtube',
#        'fuente_conocimiento_podcast', 'fuente_conocimiento_blogs',
#        'fuente_conocimiento_journal_publicacions',
#        'fuente_conocimiento_slack_communities', 'fuente_conocimiento_none',
#        'fuente_conocimiento_otros'],
#       dtype='object')

# %%
porcentaje_tabla_pequeña = round(tabla_pequeña.isnull().sum() *100 / tabla_pequeña.shape[0],2)
porcentaje_tabla_pequeña
# Out:
# Unnamed: 0                                   0.00
# indices                                      0.00
# edad                                         0.00
# genero                                       0.00
# pais                                         0.00
# formacion_2                                  0.00
# puesto_trabajo                               0.00
# años_programando                             0.00
# lenguajes_utilizados                         3.97
# lenguajes_recomendados                       3.98
# herramientas_uso                             4.82
# librerias_visualizacion                      7.71
# años_usando_machine                          8.54
# sector_trabajo_actual                       37.15
# tamaño_empresa                              37.43
# personas_dpt_data                           37.91
# salario_anual                               40.74
# inversion_dpt_machine_5años                 41.54
# plataforma_coursera                         62.85
# plataforma_edx                              88.34
# plataforma_kaggle_learn_courses             66.62
# plataforma_data_camp                        84.61
# plataforma_fast_ai                          95.55
# plataforma_udacity                          89.21
# plataforma_udemy                            75.21
# plataforma_linkedin_learning                89.63
# plataforma_cloud_certification_programs     93.05
# plataforma_university_courses               81.20
# plataforma_none                             93.22
# plataforma_otros                            91.99
# fuente_conocimiento_twitter                 85.57
# fuente_conocimiento_email                   86.75
# fuente_conocimiento_reddit                  88.68
# fuente_conocimiento_kaggle                  56.21
# fuente_conocimiento_course                  88.46
# fuente_conocimiento_youtube                 59.95
# fuente_conocimiento_podcast                 92.21
# fuente_conocimiento_blogs                   69.29
# fuente_conocimiento_journal_publicacions    87.10
# fuente_conocimiento_slack_communities       92.32
# fuente_conocimiento_none                    96.12
# fuente_conocimiento_otros                   97.76
# dtype: float64

# %% [markdown]
# Salario medio en función de: Experiencia/ genero/ pais/ sector (q25,q2, q1, q3,q6)

# %%
tabla_pequeña.head(2)
# Out:
#    Unnamed: 0  indices   edad genero       pais        formacion_2  \
# 0           0        0  50-54    Man      India  Bachelor’s degree
# 1           1        1  50-54    Man  Indonesia    Master’s degree
#
#             puesto_trabajo años_programando lenguajes_utilizados  \
# 0                    Other       5-10 years            Python, R
# 1  Program/Project Manager        20+ years    SQL, C, C++, Java
#
#   lenguajes_recomendados  ... fuente_conocimiento_reddit  \
# 0                 Python  ...                        NaN
# 1                 Python  ...                        NaN
#
#         fuente_conocimiento_kaggle fuente_conocimiento_course  \
# 0  Kaggle (notebooks, forums, etc)                        NaN
# 1                              NaN                        NaN
#
#                          fuente_conocimiento_youtube  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                          fuente_conocimiento_podcast  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                            fuente_conocimiento_blogs  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#             fuente_conocimiento_journal_publicacions  \
# 0  Journal Publications (peer-reviewed journals, ...
# 1  Journal Publications (peer-reviewed journals, ...
#
#   fuente_conocimiento_slack_communities fuente_conocimiento_none  \
# 0                                   NaN                      NaN
# 1                                   NaN                      NaN
#
#   fuente_conocimiento_otros
# 0                       NaN
# 1                       NaN
#
# [2 rows x 42 columns]

# %%
dfp1 = tabla_pequeña[["edad", "genero", "pais", "años_programando", "salario_anual", "sector_trabajo_actual", "puesto_trabajo"]]
dfp1.head(5)
# Out:
#     edad genero       pais años_programando  salario_anual  \
# 0  50-54    Man      India       5-10 years  25,000-29,999
# 1  50-54    Man  Indonesia        20+ years  60,000-69,999
# 2  22-24    Man   Pakistan        1-3 years         $0-999
# 3  45-49    Man     Mexico        20+ years  30,000-39,999
# 4  45-49    Man      India        < 1 years  30,000-39,999
#
#        sector_trabajo_actual           puesto_trabajo
# 0  Manufacturing/Fabrication                    Other
# 1  Manufacturing/Fabrication  Program/Project Manager
# 2        Academics/Education        Software Engineer
# 3        Academics/Education       Research Scientist
# 4        Academics/Education                    Other

# %%
#dfp1.to_csv("data/tabla_trabajo.csv")

# %% [markdown]
# Creamos un DataFrame sin nulos (40%) en la columna salarios, para averiguar si tiene influencia en los graficos.

# %%
dfp2 = dfp1.copy()

# %%
dfp2[dfp2["salario_anual"].isnull()]
#hemos creado un df con los nulos de salario_anual
# Out:
#         edad genero                      pais años_programando salario_anual  \
# 5      25-29  Woman                     India        < 1 years           NaN
# 6      18-21  Woman                     India        1-3 years           NaN
# 8      22-24    Man                    Russia        3-5 years           NaN
# 11     18-21  Woman                     India        < 1 years           NaN
# 12     18-21  Woman                     India        < 1 years           NaN
# ...      ...    ...                       ...              ...           ...
# 25956  40-44    Man                  Colombia      10-20 years           NaN
# 25964  22-24    Man                 Australia       5-10 years           NaN
# 25965  18-21    Man                     India        1-3 years           NaN
# 25969  22-24    Man                     China        1-3 years           NaN
# 25971  45-49    Man  United States of America       5-10 years           NaN
#
#                         sector_trabajo_actual          puesto_trabajo
# 5                                         NaN  Currently not employed
# 6                                         NaN                 Student
# 8                                         NaN  Currently not employed
# 11                                        NaN                 Student
# 12                                        NaN                 Student
# ...                                       ...                     ...
# 25956                                     NaN      Research Scientist
# 25964                                     NaN                 Student
# 25965                                     NaN            Data Analyst
# 25969                                     NaN                 Student
# 25971  Online Service/Internet-based Services          Data Scientist
#
# [10582 rows x 7 columns]

# %%
dfp2[dfp2["salario_anual"].notnull()].index
# Out:
# Int64Index([    0,     1,     2,     3,     4,     7,     9,    10,    13,
#                14,
#             ...
#             25959, 25960, 25961, 25962, 25963, 25966, 25967, 25968, 25970,
#             25972],
#            dtype='int64', length=15391)

# %%
indice_salario_sin_nul = list(dfp2[dfp2["salario_anual"].notnull()].index)

# %%
df_sin_nul = dfp2.iloc[indice_salario_sin_nul]
df_sin_nul
# Out:
#         edad genero         pais           años_programando  salario_anual  \
# 0      50-54    Man        India                 5-10 years  25,000-29,999
# 1      50-54    Man    Indonesia                  20+ years  60,000-69,999
# 2      22-24    Man     Pakistan                  1-3 years         $0-999
# 3      45-49    Man       Mexico                  20+ years  30,000-39,999
# 4      45-49    Man        India                  < 1 years  30,000-39,999
# ...      ...    ...          ...                        ...            ...
# 25966  30-34    Man        India                  1-3 years    3,000-3,999
# 25967  35-39    Man  South Korea                 5-10 years  80,000-89,999
# 25968  30-34    Man        Egypt                  1-3 years  15,000-19,999
# 25970  50-54    Man       Sweden  I have never written code         $0-999
# 25972  18-21    Man        India  I have never written code         $0-999
#
#            sector_trabajo_actual           puesto_trabajo
# 0      Manufacturing/Fabrication                    Other
# 1      Manufacturing/Fabrication  Program/Project Manager
# 2            Academics/Education        Software Engineer
# 3            Academics/Education       Research Scientist
# 4            Academics/Education                    Other
# ...                          ...                      ...
# 25966  Manufacturing/Fabrication             Data Analyst
# 25967       Computers/Technology        Software Engineer
# 25968       Computers/Technology             Data Analyst
# 25970        Academics/Education       Research Scientist
# 25972                      Other         Business Analyst
#
# [15391 rows x 7 columns]

# %% [markdown]
# Creamos una columna nueva agrupando los paises por continentes

# %%
def continentes(colum):
    asia = ['India','Indonesia','Pakistan','Japan','China','Malaysia','Thailand','Nepal','Russia','Singapore','Turkey','Hong Kong (S.A.R.)','Iran, Islamic Republic of...','Viet Nam',
            'Israel','Bangladesh','Tunisia','Saudi Arabia','Taiwan','South Korea','Philippines','Sri Lanka','United Arab Emirates','Kazakhstan','Iraq']
    america = ['United States of America','Mexico','Brazil','Peru','Ecuador','Argentina','Colombia','Canada','Chile']
    oceania = "Australia"
    africa = ['Nigeria','South Africa','Ghana','Uganda','Egypt','Morocco','Algeria','Kenya','Ethiopia']
    europa = [ 'Greece','Belgium','Italy','Norway','Czech Republic''Poland','Spain','United Kingdom of Great Britain and Northern Ireland','France','Switzerland','Netherlands',
                'Denmark','Germany','Sweden','Ireland','Portugal','Turkey','Ukraine', 'Romania','Austria','Belarus']                  
    if colum in asia:
        return "Asia"
    elif colum in america:
        return "America"
    elif colum in oceania:
        return "Oceania"
    elif colum in africa:
        return "Africa"
    elif colum in europa:
        return "Europa"
    else:
        return "Otros"

# %%
tabla_pequeña["continente"] = (tabla_pequeña["pais"].apply(continentes))

# %%
tabla_pequeña.sample()
# Out:
#      indices   edad genero   pais      formacion_2           puesto_trabajo  \
# 839      839  45-49    Man  Italy  Master’s degree  Program/Project Manager
#
#     años_programando lenguajes_utilizados lenguajes_recomendados  \
# 839      10-20 years   Python, Java, Bash                 Python
#
#     herramientas_uso  ...       fuente_conocimiento_kaggle  \
# 839         A laptop  ...  Kaggle (notebooks, forums, etc)
#
#     fuente_conocimiento_course fuente_conocimiento_youtube  \
# 839                        NaN                         NaN
#
#     fuente_conocimiento_podcast fuente_conocimiento_blogs  \
# 839                         NaN                       NaN
#
#     fuente_conocimiento_journal_publicacions  \
# 839                                      NaN
#
#     fuente_conocimiento_slack_communities fuente_conocimiento_none  \
# 839                                   NaN                      NaN
#
#     fuente_conocimiento_otros continente
# 839                       NaN     Europa
#
# [1 rows x 42 columns]

# %%
plt.figure(figsize=(10,6))

fig = sns.histplot(y="salario_anual", data=dfp1)

plt.show()

# %% [markdown]
# Nos damos cuenta de que no podemos usar el boxplot porque tenemos que cambiar el tipo de dato de la columna salario.

# %%
dfp1.head()
# Out:
#     edad genero       pais años_programando  salario_anual  \
# 0  50-54    Man      India       5-10 years  25,000-29,999
# 1  50-54    Man  Indonesia        20+ years  60,000-69,999
# 2  22-24    Man   Pakistan        1-3 years         $0-999
# 3  45-49    Man     Mexico        20+ years  30,000-39,999
# 4  45-49    Man      India        < 1 years  30,000-39,999
#
#        sector_trabajo_actual           puesto_trabajo
# 0  Manufacturing/Fabrication                    Other
# 1  Manufacturing/Fabrication  Program/Project Manager
# 2        Academics/Education        Software Engineer
# 3        Academics/Education       Research Scientist
# 4        Academics/Education                    Other

# %% [markdown]
# Intentamos hacer varias gráficas pero entre que el tipo de dato no es númerico, para el salario y que tenemos muchos registros decidimos probar a categorizar los datos del salario.

# %% [markdown]
# Hemos creado la columna de continente donde categorizamos los paises por su correspondiente continente.
#
# Decidimos pedir ayuda para el tema del salario, no sabemos si picar directamente, guardar los dos rangos en listas, crear la media de los dos rangos...

# %%
dfp1["salario_anual"].unique()
# Out:
# array(['25,000-29,999', '60,000-69,999', '$0-999', '30,000-39,999', nan,
#        '15,000-19,999', '70,000-79,999', '2,000-2,999', '10,000-14,999',
#        '5,000-7,499', '20,000-24,999', '1,000-1,999', '100,000-124,999',
#        '7,500-9,999', '4,000-4,999', '40,000-49,999', '50,000-59,999',
#        '3,000-3,999', '300,000-499,999', '200,000-249,999',
#        '125,000-149,999', '250,000-299,999', '80,000-89,999',
#        '90,000-99,999', '150,000-199,999', '>$1,000,000',
#        '$500,000-999,999'], dtype=object)

# %%
dfp1[dfp1["salario_anual"] == '>$1,000,000']
# Out:
#         edad                   genero  \
# 658      70+                      Man
# 1831   55-59                      Man
# 1975   35-39                      Man
# 1987   22-24                      Man
# 2087   40-44                      Man
# 3556   40-44                      Man
# 4375   22-24                    Woman
# 4752   35-39                Nonbinary
# 5035   22-24                      Man
# 5282   45-49                      Man
# 5508   40-44                      Man
# 6274   22-24                      Man
# 6514   45-49                      Man
# 6543   18-21                      Man
# 7093   25-29                      Man
# 7189     70+                Nonbinary
# 7318   40-44                      Man
# 7773   25-29                    Woman
# 7856   30-34                      Man
# 8166   35-39                      Man
# 9621   45-49                      Man
# 9769   60-69                      Man
# 10468  30-34                Nonbinary
# 10712  25-29        Prefer not to say
# 11026  25-29                      Man
# 11926  30-34                      Man
# 12721  35-39                      Man
# 14125  22-24                      Man
# 14365  35-39                      Man
# 14984  40-44                    Woman
# 15366  55-59                      Man
# 16882  35-39                      Man
# 17239  22-24                      Man
# 17518  30-34                      Man
# 17566  30-34                      Man
# 18425  22-24                      Man
# 19113  40-44                      Man
# 19902  22-24  Prefer to self-describe
# 19944  40-44                      Man
# 19998  35-39                      Man
# 20310  25-29                      Man
# 20339  18-21                      Man
# 20599  45-49                      Man
# 20759  40-44                      Man
# 21128  22-24                      Man
# 22238  18-21                      Man
# 22468  45-49                      Man
# 23599  55-59        Prefer not to say
# 23884  35-39                      Man
# 24037  30-34                      Man
# 24074  30-34                      Man
# 24147  22-24                      Man
# 24154  40-44                      Man
# 24535  22-24                      Man
# 24805  25-29                      Man
# 25111  22-24                      Man
# 25328  40-44                    Woman
# 25911  18-21                      Man
#
#                                                     pais  \
# 658                                                Italy
# 1831                            United States of America
# 1975                                               Japan
# 1987                                            Pakistan
# 2087                                              France
# 3556                            United States of America
# 4375                                               India
# 4752                            United States of America
# 5035                                               Nepal
# 5282   United Kingdom of Great Britain and Northern I...
# 5508                                         South Korea
# 6274                                               India
# 6514                            United States of America
# 6543                                               India
# 7093                                             Germany
# 7189                                               Other
# 7318                            United States of America
# 7773                                              France
# 7856                            United States of America
# 8166                                             Austria
# 9621                                              Israel
# 9769                                               Other
# 10468                                          Indonesia
# 10712                                              India
# 11026                                              China
# 11926                           United States of America
# 12721                                             Israel
# 14125                                              India
# 14365                           United States of America
# 14984                                        South Korea
# 15366                                          Indonesia
# 16882                                            Nigeria
# 17239                                              Other
# 17518                                              India
# 17566                           United States of America
# 18425                                              India
# 19113                           United States of America
# 19902                                              Other
# 19944                                             Israel
# 19998                                            Germany
# 20310                           United States of America
# 20339                                              India
# 20599                                          Argentina
# 20759                                        Switzerland
# 21128                                              China
# 22238                                             Russia
# 22468                                             Russia
# 23599                           United States of America
# 23884                                             Russia
# 24037                           United States of America
# 24074                           United States of America
# 24147                                              India
# 24154                                            Romania
# 24535                                              India
# 24805                               United Arab Emirates
# 25111                                              India
# 25328                           United States of America
# 25911                                              India
#
#                 años_programando salario_anual  \
# 658                    20+ years   >$1,000,000
# 1831                   20+ years   >$1,000,000
# 1975                  5-10 years   >$1,000,000
# 1987                   1-3 years   >$1,000,000
# 2087                 10-20 years   >$1,000,000
# 3556                   20+ years   >$1,000,000
# 4375                   3-5 years   >$1,000,000
# 4752                   1-3 years   >$1,000,000
# 5035                   < 1 years   >$1,000,000
# 5282                   20+ years   >$1,000,000
# 5508                   1-3 years   >$1,000,000
# 6274                   1-3 years   >$1,000,000
# 6514                 10-20 years   >$1,000,000
# 6543                   3-5 years   >$1,000,000
# 7093                 10-20 years   >$1,000,000
# 7189   I have never written code   >$1,000,000
# 7318                   20+ years   >$1,000,000
# 7773                   < 1 years   >$1,000,000
# 7856                 10-20 years   >$1,000,000
# 8166                  5-10 years   >$1,000,000
# 9621                   20+ years   >$1,000,000
# 9769                   20+ years   >$1,000,000
# 10468                  3-5 years   >$1,000,000
# 10712                 5-10 years   >$1,000,000
# 11026                  20+ years   >$1,000,000
# 11926                10-20 years   >$1,000,000
# 12721                  3-5 years   >$1,000,000
# 14125                  3-5 years   >$1,000,000
# 14365                  20+ years   >$1,000,000
# 14984  I have never written code   >$1,000,000
# 15366                  20+ years   >$1,000,000
# 16882                 5-10 years   >$1,000,000
# 17239  I have never written code   >$1,000,000
# 17518                 5-10 years   >$1,000,000
# 17566                 5-10 years   >$1,000,000
# 18425                  3-5 years   >$1,000,000
# 19113                10-20 years   >$1,000,000
# 19902                  3-5 years   >$1,000,000
# 19944                  < 1 years   >$1,000,000
# 19998                  < 1 years   >$1,000,000
# 20310                10-20 years   >$1,000,000
# 20339                  1-3 years   >$1,000,000
# 20599                 5-10 years   >$1,000,000
# 20759                  20+ years   >$1,000,000
# 21128                  1-3 years   >$1,000,000
# 22238                  1-3 years   >$1,000,000
# 22468                10-20 years   >$1,000,000
# 23599                  20+ years   >$1,000,000
# 23884                10-20 years   >$1,000,000
# 24037                 5-10 years   >$1,000,000
# 24074                10-20 years   >$1,000,000
# 24147                  3-5 years   >$1,000,000
# 24154                  3-5 years   >$1,000,000
# 24535                  < 1 years   >$1,000,000
# 24805                  < 1 years   >$1,000,000
# 25111                  1-3 years   >$1,000,000
# 25328                  20+ years   >$1,000,000
# 25911                  1-3 years   >$1,000,000
#
#                         sector_trabajo_actual                puesto_trabajo
# 658                             Marketing/CRM  Developer Relations/Advocacy
# 1831                     Computers/Technology                Data Scientist
# 1975                Manufacturing/Fabrication                Data Scientist
# 1987                            Energy/Mining                         Other
# 2087                     Computers/Technology       Program/Project Manager
# 3556                     Computers/Technology     Machine Learning Engineer
# 4375                     Computers/Technology             Software Engineer
# 4752                       Accounting/Finance  Developer Relations/Advocacy
# 5035                     Computers/Technology             Software Engineer
# 5282                     Computers/Technology             Software Engineer
# 5508                     Computers/Technology                 Data Engineer
# 6274                       Accounting/Finance                Data Scientist
# 6514                     Computers/Technology                Data Scientist
# 6543   Online Service/Internet-based Services             Software Engineer
# 7093                     Computers/Technology                         Other
# 7189                       Non-profit/Service                         Other
# 7318                       Accounting/Finance                Data Scientist
# 7773                   Medical/Pharmaceutical              Business Analyst
# 7856                       Accounting/Finance                Data Scientist
# 8166                      Academics/Education            Research Scientist
# 9621                     Computers/Technology             Software Engineer
# 9769                      Academics/Education                  Statistician
# 10468                            Retail/Sales       Program/Project Manager
# 10712                      Accounting/Finance             Software Engineer
# 11026                    Computers/Technology     Machine Learning Engineer
# 11926                    Computers/Technology     Machine Learning Engineer
# 12721                    Computers/Technology                         Other
# 14125                      Non-profit/Service                Data Scientist
# 14365               Government/Public Service              Business Analyst
# 14984                           Marketing/CRM                         Other
# 15366                    Computers/Technology                Data Scientist
# 16882                           Energy/Mining             Software Engineer
# 17239                    Computers/Technology             Software Engineer
# 17518                      Accounting/Finance               Product Manager
# 17566                     Academics/Education                  Data Analyst
# 18425                    Computers/Technology                 Data Engineer
# 19113                      Accounting/Finance                Data Scientist
# 19902                                   Other                         Other
# 19944                    Computers/Technology               Product Manager
# 19998  Online Service/Internet-based Services                  Data Analyst
# 20310    Online Business/Internet-based Sales             Software Engineer
# 20339                     Academics/Education                Data Scientist
# 20599                      Accounting/Finance              Business Analyst
# 20759                    Computers/Technology                         Other
# 21128                     Academics/Education       Program/Project Manager
# 22238                     Academics/Education     Machine Learning Engineer
# 22468                    Computers/Technology             Software Engineer
# 23599                    Computers/Technology                         Other
# 23884                            Retail/Sales             Software Engineer
# 24037                      Accounting/Finance                Data Scientist
# 24074                      Accounting/Finance                         Other
# 24147                    Computers/Technology                Data Scientist
# 24154               Manufacturing/Fabrication              Business Analyst
# 24535                    Computers/Technology                Data Scientist
# 24805               Insurance/Risk Assessment                         Other
# 25111                    Computers/Technology             Software Engineer
# 25328    Online Business/Internet-based Sales                         Other
# 25911                     Academics/Education                Data Scientist

# %%
dfp11 = dfp1[dfp1["salario_anual"] == '>$1,000,000']

# %%
dfp1.head(2)
# Out:
#     edad genero       pais años_programando  salario_anual  \
# 0  50-54    Man      India       5-10 years  25,000-29,999
# 1  50-54    Man  Indonesia        20+ years  60,000-69,999
#
#        sector_trabajo_actual           puesto_trabajo
# 0  Manufacturing/Fabrication                    Other
# 1  Manufacturing/Fabrication  Program/Project Manager

# %%
dfp11["salario_anual"].value_counts()
# Out:
# >$1,000,000    58
# Name: salario_anual, dtype: int64

# %%
def sueldo_a_int(column):        
    try:
        return int(column.replace(",", "").replace("$","").replace(">","").split("-")[0])
    except:
        return np.nan

#fichero_peliculas["Year"] = (fichero_peliculas["Released_Year"].apply(año_a_int))

# %%
def sueldo_a_int_max(column):
    column2 = str(column).lower()
    if column2 == "nan":
        return np.nan
    else:
        lista = column2.replace(",", "").replace("$","").replace(">","").split("-")
        if len(lista) == 1:
            return 1000000
        else:
            return int(lista[1])

# %%
dfp1["rango_salario_minimo"] = (dfp1["salario_anual"].apply(sueldo_a_int))
# Out:
# /tmp/ipykernel_1154/1105135628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1["rango_salario_minimo"] = (dfp1["salario_anual"].apply(sueldo_a_int))

# %%
dfp1["rango_salario_maximo"] = (dfp1["salario_anual"].apply(sueldo_a_int_max))
# Out:
# /tmp/ipykernel_1154/2523971154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1["rango_salario_maximo"] = (dfp1["salario_anual"].apply(sueldo_a_int_max))

# %% [markdown]
# La prox vez --- Hacer la grafica con los subplots.

# %%
dfp1["continente"] = (dfp1["pais"].apply(continentes))
# Out:
# /tmp/ipykernel_1154/2879995159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfp1["continente"] = (dfp1["pais"].apply(continentes))

# %%
dfp1.head(2)
# Out:
#     edad genero       pais años_programando  salario_anual  \
# 0  50-54    Man      India       5-10 years  25,000-29,999
# 1  50-54    Man  Indonesia        20+ years  60,000-69,999
#
#        sector_trabajo_actual           puesto_trabajo  rango_salario_minimo  \
# 0  Manufacturing/Fabrication                    Other               25000.0
# 1  Manufacturing/Fabrication  Program/Project Manager               60000.0
#
#    rango_salario_maximo continente
# 0               29999.0       Asia
# 1               69999.0       Asia

# %%
dfp1.to_csv("data/1_tabla_trabajo.csv")

# %% [markdown]
# Hemos creado un csv de los sin nulos en el fichero de 03, por facilidad, ya que ahí teníamos ya todas las columnas, pero dejamos el código aquí.
#
#
# - df2 = df.copy()
# - df2[df2["salario_anual"].notnull()].index
# - indice_salario_sin_nul = list(df2[df2["salario_anual"].notnull()].index)
# - df_sin_nul = df2.iloc[indice_salario_sin_nul]
# - df_sin_nul.info()
# - df_sin_nul.to_csv("data/2_tabla_trabajo_sin_nulos.csv")
